# %%
import numpy as np
import pandas as pd

address = 'C:/Users/RONALD Q/OneDrive - LUZ DEL SUR S.A.A/Documentos/Estudios de Ingreso/ProyectoR&D/Basededatos/RTRA.xlsx'
address2 = 'C:/Users/roquispec/OneDrive - LUZ DEL SUR S.A.A/Documentos/Estudios de Ingreso/ProyectoR&D/Basededatos/RTRA.xlsx'
address3 = 'C:\\Users\\mticllacu\\OneDrive - LUZ DEL SUR S.A.A\\Archivos de Ronald Quispe Ocaña - ProyectoR&D\\Basededatos\\RTRA.xlsx'
#df = pd.read_excel(address, header=1)
df = pd.read_excel(address2, header=1)

# %%
df = df.iloc[:,1:]
df
# Out:
#     SERIE      FECHA  H-X POS1 R  H-X POS2 R  H-X POS3 R  H-X POS4 R  \
# 0  146916 2019-06-30    3.768769    3.744405    3.707801    3.671139
# 1  146916 2015-01-06    3.771300    3.746000    3.709000    3.672300
# 2  146916 2014-11-12    3.772695    3.740075    3.707455    3.674834
# 3  146917 2022-05-12    2.852500    2.824700    2.796900    2.778400
# 4  146917 2014-12-05    2.853000    2.825500    2.797700    2.779200
#
#    H-X POS5 R  H-X POS6 R  H-X POS7 R  H-X POS8 R  ...  H-Y POS21 T  \
# 0    3.646833    3.610171    3.573509    3.549145  ...          NaN
# 1    3.647800    3.611200    3.574500    3.550200  ...          NaN
# 2    3.642214    3.609594    3.576974    3.544353  ...          NaN
# 3    2.750500    2.722700    2.704100    2.676400  ...          NaN
# 4    2.751600    2.723500    2.704900    2.677000  ...          NaN
#
#    H-Y POS22 T  H-Y POS23 T  H-Y POS24 T  H-Y POS25 T  H-Y POS26 T  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
# Asegurar que FECHA sea datetime
df["FECHA"] = pd.to_datetime(df["FECHA"])

# Seleccionar las columnas de resistencia (las que terminan en "R", "S" o "T")
res_cols = [c for c in df.columns if c.endswith(("R", "S", "T"))]

for col in res_cols:
    # Valor inicial por SERIE en la fecha mínima
    ref = df.groupby("SERIE").apply(lambda g: g.loc[g["FECHA"].idxmin(), col])
    ref_mapped = df["SERIE"].map(ref)

    # Variación porcentual
    delta = abs((df[col] - ref_mapped) / ref_mapped) * 100

    # Reemplazar inf por NaN (división por cero)
    delta = delta.replace([np.inf, -np.inf], np.nan)

    # Condiciones extra: si hay NaN o valores = 0 → NaN
    mask = df[col].isna() | ref_mapped.isna() | (ref_mapped == 0) | (df[col] == 0)
    delta[mask] = np.nan

    # Agregar nueva columna
    df[f"{col}_Delta"] = delta
# Out:
# C:\Users\roquispec\AppData\Local\Temp\ipykernel_31952\3992010179.py:9: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ref = df.groupby("SERIE").apply(lambda g: g.loc[g["FECHA"].idxmin(), col])
# C:\Users\roquispec\AppData\Local\Temp\ipykernel_31952\3992010179.py:9: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ref = df.groupby("SERIE").apply(lambda g: g.loc[g["FECHA"].idxmin(), col])
# ...

# %%
df.head()
# Out:
#     SERIE      FECHA  H-X POS1 R  H-X POS2 R  H-X POS3 R  H-X POS4 R  \
# 0  146916 2019-06-30    3.768769    3.744405    3.707801    3.671139
# 1  146916 2015-01-06    3.771300    3.746000    3.709000    3.672300
# 2  146916 2014-11-12    3.772695    3.740075    3.707455    3.674834
# 3  146917 2022-05-12    2.852500    2.824700    2.796900    2.778400
# 4  146917 2014-12-05    2.853000    2.825500    2.797700    2.779200
#
#    H-X POS5 R  H-X POS6 R  H-X POS7 R  H-X POS8 R  ...  H-Y POS21 T_Delta  \
# 0    3.646833    3.610171    3.573509    3.549145  ...                NaN
# 1    3.647800    3.611200    3.574500    3.550200  ...                NaN
# 2    3.642214    3.609594    3.576974    3.544353  ...                NaN
# 3    2.750500    2.722700    2.704100    2.676400  ...                NaN
# 4    2.751600    2.723500    2.704900    2.677000  ...                NaN
#
#    H-Y POS22 T_Delta  H-Y POS23 T_Delta  H-Y POS24 T_Delta  H-Y POS25 T_Delta  \
# ...

# %%
# Identificar las columnas que terminan en "_Delta"
delta_cols = [c for c in df.columns if c.endswith("_Delta")]

# Crear una nueva columna con el máximo por fila
df["Max_Delta"] = df[delta_cols].max(axis=1)
# Out:
# C:\Users\roquispec\AppData\Local\Temp\ipykernel_31952\1286000598.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["Max_Delta"] = df[delta_cols].max(axis=1)

# %%
# Crear columna de puntaje para Max_Delta
df["RTRA"] = df["Max_Delta"].apply(
    lambda x: np.nan if pd.isna(x) else (5 if x > 0.5 else 1)
)
# Out:
# C:\Users\roquispec\AppData\Local\Temp\ipykernel_31952\2962016841.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["RTRA"] = df["Max_Delta"].apply(

# %%
df.head()
# Out:
#     SERIE      FECHA  H-X POS1 R  H-X POS2 R  H-X POS3 R  H-X POS4 R  \
# 0  146916 2019-06-30    3.768769    3.744405    3.707801    3.671139
# 1  146916 2015-01-06    3.771300    3.746000    3.709000    3.672300
# 2  146916 2014-11-12    3.772695    3.740075    3.707455    3.674834
# 3  146917 2022-05-12    2.852500    2.824700    2.796900    2.778400
# 4  146917 2014-12-05    2.853000    2.825500    2.797700    2.779200
#
#    H-X POS5 R  H-X POS6 R  H-X POS7 R  H-X POS8 R  ...  H-Y POS23 T_Delta  \
# 0    3.646833    3.610171    3.573509    3.549145  ...                NaN
# 1    3.647800    3.611200    3.574500    3.550200  ...                NaN
# 2    3.642214    3.609594    3.576974    3.544353  ...                NaN
# 3    2.750500    2.722700    2.704100    2.676400  ...                NaN
# 4    2.751600    2.723500    2.704900    2.677000  ...                NaN
#
#    H-Y POS24 T_Delta  H-Y POS25 T_Delta  H-Y POS26 T_Delta  H-Y POS27 T_Delta  \
# ...

# %%
df_RTRA = df[['SERIE','FECHA','RTRA']]
df_RTRA.head()
# Out:
#     SERIE      FECHA  RTRA
# 0  146916 2019-06-30     1
# 1  146916 2015-01-06     5
# 2  146916 2014-11-12     1
# 3  146917 2022-05-12     1
# 4  146917 2014-12-05     1
