# %% [markdown]
# ```mermaid
# flowchart TD
#     %% ========== FUENTES DE DATOS ==========
#     A([🏁 Inicio del Proceso]) --> B{🔄 Fuentes de Datos}
#
#     B --> C[/📊 Archivos Excel/]
#     B --> D[/⚡ SCADA<br>Voltaje Excitación<br>Cada 15 min/]
#     B --> E[/🐍 Scripts Python<br>Extracción/]
#
#     %% ========== PROCESAMIENTO ETL ==========
#     C --> F{Procesamiento ETL<br>Python}
#     D --> F
#     E --> F
#
#     F --> G[[🔧 Limpieza de Datos]]
#     G --> H[[🔄 Transformaciones]]
#     H --> I[[✅ Validaciones]]
#
#     %% ========== ALMACENAMIENTO ==========
#     I --> J{Almacenamiento<br>PostgreSQL}
#
#     J --> K[🏭 BD_Transformadores<br>Tablas Principales]
#
#     %% ========== ESTRUCTURA TABLAS ==========
#     K --> L{Tablas por Subíndice}
#
#     L --> M[🔄 Tablas Base<br>hidga, ace, etc.]
#     L --> N[📈 Tablas Extendidas<br>hidga_extendido, etc.]
#
#     %% ========== POWER BI ==========
#     M --> O{Modelado<br>Power BI}
#     N --> O
#
#     O --> P[[📅 BD_Calendario<br>Generado en Power BI]]
#     O --> Q[[📊 BD_Medidas DAX<br>Creadas en Power BI]]
#     O --> R[[🤝 Relaciones de Tablas]]
#
#     R --> S[[🔗 Configuración<br>Drill-through]]
#
#     %% ========== DASHBOARDS ==========
#     S --> T{Dashboards<br>Interactivos}
#
#     T --> U[📋 Tabla General<br>Vista Inicial]
#     T --> V[🔍 Páginas Detalladas<br>Drill-through]
#
#     %% ========== SUBÍNDICES PRINCIPALES ==========
#     V --> W{7 Subíndices<br>Principales}
#
#     W --> X[🎯 DGA]
#     W --> Y[🛢️ ACE]
#     W --> Z[⚡ AIS]
#     W --> AA[🔧 ARR]
#     W --> BB[🧲 NUC]
#     W --> CC[🔌 OLTC]
#     W --> DD[🏗️ BUS]
#
#     %% ========== SUB-SUBÍNDICES ==========
#     Z --> Z1[VUT]
#     Z --> Z2[ECC]
#     Z --> Z3[FUR]
#     Z --> Z4[FP]
#     Z --> Z5[CD]
#
#     AA --> AA1[ROHM]
#     AA --> AA2[RTRA]
#     AA --> AA3[RDIS]
#
#     BB --> BB1[VEX]
#     BB --> BB2[IEX]
#     BB --> BB3[RNUC]
#
#     %% ========== FUTURO ==========
#     DD --> EE([🚀 Machine Learning<br>Próxima Fase])
#
#     EE --> FF{🔮 Predicciones}
#     FF --> GG[📈 Predicción de Fallas DGA]
#     FF --> HH[⚡ Análisis de Tendencias]
#     FF --> II[🔧 Mantenimiento Predictivo]
#     FF --> JJ[🚨 Alertas Tempranas]
#
#     GG --> KK([🏁 Fin del Proceso])
#
#     %% ========== ESTILOS ==========
#     style A fill:#4CAF50,color:white
#     style KK fill:#F44336,color:white
#     style B fill:#2196F3,color:white
#     style F fill:#9C27B0,color:white
#     style J fill:#FF9800,color:white
#     style O fill:#607D8B,color:white
#     style T fill:#795548,color:white
#     style W fill:#009688,color:white
#     style EE fill:#E91E63,color:white
#     style P fill:#FFC107,color:black
#     style Q fill:#FFC107,color:black
